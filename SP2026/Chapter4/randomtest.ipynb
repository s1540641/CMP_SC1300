# %%
##
#  This program prints ten random numbers between 0 and 1.
#

from random import random

for i in range(10) :
   value = random()
   print(value)
# Out:
# 0.4460639783514637
# 0.9883977975716035
# 0.8394907369834805
# 0.8718476027521297
# 0.5404480174600177
# 0.3503477095103035
# 0.9638454273405979
# 0.39432000654636856
# 0.48260636647547206
# 0.08552799563801661
