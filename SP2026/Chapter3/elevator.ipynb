# %%
# floor_number
# real_floor_number

floor_number = int(input("Enter floor number: "))

if floor_number >= 13:
    real_floor_number = floor_number + 1
    print("It is after an unlucky number")
else:
    real_floor_number = floor_number
    print("It is before an unlucky number")

print("Real floor number ", real_floor_number)
# Out:
# Enter floor number:  15
# It is after an unlucky number
# Real floor number  16

# %%
floor_number = int(input("Enter floor number"))

if floor_number >= 13:
    floor_number = floor_number + 1
    print("It is after unlucky")

print("Adjusted floor number: ", floor_number)
# Out:
# Enter floor number 13
# It is after unlucky
# Adjusted floor number:  14

# %%
# floor_number
# real_floor_number
# print something specific when it is 13
# print something specific when it is 14

floor_number = int(input("Enter floor number: "))

if floor_number == 13:
    real_floor_number = floor_number + 2
    print("It is the unlucky number 13")
elif floor_number == 14:
    real_floor_number = floor_number + 2
    print("It is the unlucky number 14")
elif floor_number > 14:
    real_floor_number = floor_number + 2  
else:
    real_floor_number = floor_number
    print("It is before an unlucky number")

print("Real floor number ", real_floor_number)
# Out:
# Enter floor number:  16
# Real floor number  18
